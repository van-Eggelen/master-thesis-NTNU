# %% [markdown]
# # First look at datasets

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

# %%
#import self-made functions
# %run '/Users/mariekececilia/Documents/master_thesis_code/methods.ipynb'

# %% [markdown]
# ## Load Data

# %%
gexp_g, flux_g = load_gerosa()
gexp_i, flux_i = load_ishii()

# %% [markdown]
# ## Sizes, datatypes and missing values

# %% [markdown]
# Check sizes and comparability:

# %%
print('Gerosa')
print(gexp_g.shape)
print(flux_g.shape)
print('Equal index:', (gexp_g.index == flux_g.index).sum())
print('\nIshii')
print(gexp_i.shape)
print(flux_i.shape)
print('Equal index:', (gexp_i.index == flux_i.index).sum())
# Out:
# Gerosa
# (8, 4150)
# (8, 40)
# Equal index: 8
#
# Ishii
# (29, 79)
# (29, 46)
# Equal index: 29

# %% [markdown]
# --> There are many more features than samples. There are as many samples in the gene expression data as in the flux data, and they are all given in the same order.

# %% [markdown]
# Check that datatypes are loaded as expected:

# %%
print('Non-numeric entries:')
print(gexp_g.dtypes[gexp_g.dtypes != 'float64'])
print(flux_g.dtypes[flux_g.dtypes != 'float64'])
print(gexp_i.dtypes[gexp_i.dtypes != 'float64'])
print(flux_i.dtypes[flux_i.dtypes != 'float64'])
# Out:
# Non-numeric entries:
# Series([], dtype: object)
# Series([], dtype: object)
# Series([], dtype: object)
# Series([], dtype: object)

# %% [markdown]
# --> all entries are numeric, but they could still be NaN.

# %% [markdown]
# Check whether missing values (NaN) are present:

# %%
print(gexp_g.isna().sum().sum())
print(flux_g.isna().sum().sum())
print(gexp_i.isna().sum().sum())
print(flux_i.isna().sum().sum())
# Out:
# 0
# 0
# 0
# 0

# %% [markdown]
# --> There are no missing values in the data.

# %% [markdown]
# ## Size of intersection

# %%
print('Common genes:', len(get_intersection(gexp_g, gexp_i)))
print('Common reactions:', len(get_intersection(flux_i, flux_g)))
# Out:
# Common genes: 79
# Common reactions: 32

# %% [markdown]
# --> all genes in Ishii are present in Gerosa (because there are 79 genes in Ishii)

# %% [markdown]
# ## Duplicates?

# %% [markdown]
# ### Rows: samples

# %%
print('Duplicated samples in transcriptomics:')
print('Gerosa:')
display(gexp_g[gexp_g.duplicated(keep = False)].sort_values(by = gexp_g.columns[1]))
print('Ishii:')
display(gexp_i[gexp_i.duplicated(keep = False)].sort_values(by = gexp_i.columns[1]))

print('Duplicated samples in fluxomics:')
print('Gerosa:')
display(flux_g[flux_g.duplicated(keep = False)].sort_values(by = flux_g.columns[1]))
print('Ishii:')
display(flux_i[flux_i.duplicated(keep = False)].sort_values(by = flux_i.columns[1]))
# Out:
# Duplicated samples in transcriptomics:
# Gerosa:
# Empty DataFrame
# Columns: [b0002, b0003, b0004, b0005, b0006, b0007, b0008, b0009, b0010, b0011, b0013, b0014, b0015, b0016, b0018, b0019, b0020, b0021, b0022, b0023, b0024, b0025, b0026, b0027, b0028, b0029, b0030, b0031, b0032, b0033, b0034, b0035, b0036, b0037, b0038, b0039, b0040, b0041, b0042, b0043, b0044, b0045, b0046, b0047, b0048, b0049, b0050, b0051, b0052, b0053, b0054, b0055, b0058, b0059, b0060, b0061, b0062, b0063, b0064, b0065, b0066, b0067, b0068, b0069, b0070, b0071, b0072, b0073, b0074, b0076, b0077, b0078, b0080, b0081, b0082, b0083, b0084, b0085, b0086, b0087, b0088, b0089, b0090, b0091, b0092, b0093, b0094, b0095, b0096, b0097, b0098, b0099, b0101, b0102, b0103, b0104, b0106, b0107, b0108, b0109, ...]
# Index: []
#
# [0 rows x 4150 columns]
# Ishii:
# Empty DataFrame
# Columns: [b0008, b0114, b0115, b0116, b0118, b0333, b0474, b0688, b0720, b0721, b0722, b0723, b0724, b0726, b0727, b0728, b0729, b0755, b0756, b0767, b0871, b0902, b0903, b1101, b1136, b1241, b1276, b1380, b1602, b1603, b1611, b1612, b1676, b1702, b1723, b1779, b1850, b1851, b1852, b1854, b2029, b2097, b2133, b2296, b2297, b2388, b2415, b2416, b2417, b2463, b2464, b2465, b2779, b2914, b2925, b2926, b2935, b2976, b3236, b3386, b3403, b3605, b3612, b3916, b3919, b3951, b3952, b3956, b4014, b4015, b4025, b4069, b4090, b4122, b4151, b4152, b4153, b4154, b4232]
# Index: []
#
# [0 rows x 79 columns]
# Duplicated samples in fluxomics:
# Gerosa:
# Empty DataFrame
# Columns: [R_EX_ac_e, R_EX_fru_e, R_EX_gal_e, R_EX_glc_e, R_EX_glyc_e, R_EX_glcn_e, R_EX_pyr_e, R_EX_succ_e, R_EX_fum_e, R_EX_lac_D_e, R_PGI, R_FBA, R_TPI, R_GAPD, R_PGK, R_PGM, R_ENO, R_PDH, R_EDD, R_EDA, R_G6PDH2r, R_PGL, R_GND, R_RPI, R_RPE, R_TKT1, R_TALA, R_TKT2, R_PPC, R_PPCK, R_CS, R_ACONTa, R_ACONTb, R_ICDHyr, R_AKGDH, R_SUCOAS, R_SUCDi, R_FUM, R_ICL, R_MALS]
# Index: []
#
# [0 rows x 40 columns]
# Ishii:
# Empty DataFrame
# Columns: [R_GLCptspp, R_PGI, R_PFK, R_FBA, R_TPI, R_PGK, R_GAPD, R_ENO, R_PGM, R_PYK, R_PDH, R_G6PDH2r, R_PGL, R_GND, R_RPE, R_RPI, R_TKT1, R_TALA, R_TKT2, R_CS, R_ACONTb, R_ACONTa, R_ICDHyr, R_SUCOAS, R_AKGDH, R_SUCDi, R_FUM, R_MDH, R_PPC, R_ME2, R_ICL, R_MALS, R_ACKr, R_PTAr, R_LDH_D, R_ACALD, R_ALCD2x, R_EX_glc_e, R_EX_o2_e, R_EX_co2_e, R_EX_etoh_e, R_EX_ac_e, R_EX_lac_D_e, R_EX_succ_e, R_EX_pyr_e, R_EX_for_e]
# Index: []
#
# [0 rows x 46 columns]

# %% [markdown]
# --> No samples are duplicates of one another.

# %% [markdown]
# ### Columns: features or targets

# %%
print('Duplicated genes and their expression levels:')
print('Gerosa:')
display(gexp_g.T[gexp_g.T.duplicated(keep = False)].sort_values(by = gexp_g.T.columns[0]))
print('Ishii:')
display(gexp_i.T[gexp_i.T.duplicated(keep = False)].sort_values(by = gexp_i.T.columns[0]))

#Consider absolute values for fluxes
print('Duplicated reactions and their fluxes:')
print('Gerosa:')
display(flux_g.T[flux_g.abs().T.duplicated(keep = False)].sort_values(by = flux_g.T.columns[0]))
# R_PGM        -5.2438 -5.0184 -2.9757 -4.4064  ... -5.4378 -5.4432 -5.0516
# R_EX_glc_e   -3.1400 -3.0600 -2.7300 -2.7200  ... -3.1800 -3.3600 -2.9200
# R_SUCOAS     -2.6062 -2.2644 -0.9009 -1.7408  ... -2.1624 -2.1840 -2.4820
# R_ALCD2x     -0.0000 -0.0000 -0.0000 -0.0000  ... -0.0000 -0.0000 -0.0000
# R_ACALD      -0.0000 -0.0000 -0.0000 -0.0000  ... -0.0000 -0.0000 -0.0000
# R_EX_lac_D_e  0.0000  0.0000  0.0000  0.0000  ...  0.0000  0.0000  0.0000
# R_PTAr        0.0000  0.0000  0.0000  0.0000  ...  0.0000  0.0000  0.0000
# R_LDH_D      -0.0000 -0.0000 -0.0000 -0.0000  ... -0.0000 -0.0000 -0.0000
# R_ACKr       -0.0000 -0.0000 -0.0000 -0.0000  ... -0.0000 -0.0000 -0.0000
# R_TALA        0.0942  0.1836  0.5187  0.0816  ... -0.0318  0.2016 -0.0292
# R_TKT1        0.0942  0.1836  0.5187  0.0816  ... -0.0318  0.2016 -0.0292
# R_MALS        0.2198  0.3366  0.6825  0.2176  ...  0.8586  0.5040  0.4672
# R_ICL         0.2198  0.3366  0.6825  0.2176  ...  0.8586  0.5040  0.4672
# R_PGL         0.3768  0.6426  1.6653  0.3808  ...  0.0000  0.6720  0.0000
# R_GND         0.3768  0.6426  1.6653  0.3808  ...  0.0000  0.6720  0.0000
# R_AKGDH       2.6062  2.2644  0.9009  1.7408  ...  2.1624  2.1840  2.4820
# R_SUCDi       2.8574  2.6010  1.5834  1.9856  ...  3.0210  2.6880  2.9492
# R_FUM         2.8574  2.6010  1.5834  1.9856  ...  3.0210  2.6880  2.9492
# R_TPI         2.7946  2.6316  0.9282  2.3664  ...  2.9574  2.8896  2.7156
# R_FBA         2.7946  2.6316  0.9282  2.3664  ...  2.9574  2.8896  2.7156
# R_PFK         2.7946  2.6316  0.9282  2.3664  ...  2.9574  2.8896  2.7156
# R_ACONTb      3.0772  2.8458  1.8291  2.2304  ...  3.2754  2.9568  3.1536
# R_CS          3.0772  2.8458  1.8291  2.2304  ...  3.2754  2.9568  3.1536
# R_ACONTa      3.0772  2.8458  1.8291  2.2304  ...  3.2754  2.9568  3.1536
# R_GLCptspp    3.1400  3.0600  2.7300  2.7200  ...  3.1800  3.3600  2.9200
# R_ENO         5.2438  5.0184  2.9757  4.4064  ...  5.4378  5.4432  5.0516
# R_GAPD        5.5578  5.2938  3.2760  4.7056  ...  5.7558  5.8128  5.3144
#
#                  rpe    rpiA    rpiB    tktA    tktB   talA    talB
# R_PGK        -6.5703 -4.9926 -7.0135 -7.6779 -5.1975 -4.872 -5.1450
# R_PGM        -6.2799 -4.7064 -6.7230 -7.3636 -4.9005 -4.564 -4.8510
# R_EX_glc_e   -3.6300 -3.1800 -4.1500 -4.4900 -2.9700 -2.800 -2.9400
# R_SUCOAS     -3.1581 -2.2896 -3.9425 -5.5227 -2.4948 -2.100 -2.3814
# R_ALCD2x     -0.0726 -0.0000 -0.0000 -0.0000 -0.0000 -0.000 -0.0000
# R_ACALD      -0.0726 -0.0000 -0.0000 -0.0000 -0.0000 -0.000 -0.0000
# R_EX_lac_D_e  0.0000  0.0000  0.0000  0.0000  0.0000  0.000  0.0000
# R_PTAr        0.0000  0.0000  0.0000  0.0000  0.0000  0.000  0.0000
# R_LDH_D      -0.0000 -0.0000 -0.0000 -0.0000 -0.0000 -0.000 -0.0000
# R_ACKr       -0.0000 -0.0000 -0.0000 -0.0000 -0.0000 -0.000 -0.0000
# R_TALA        0.0363  0.0954  0.6225  0.0898  0.0891  0.084  0.0882
# R_TKT1        0.0363  0.0954  0.6225  0.0898  0.0891  0.084  0.0882
# R_MALS        0.6171  0.6360  0.3320  0.0000  0.0000  0.056  0.0588
# R_ICL         0.6171  0.6360  0.3320  0.0000  0.0000  0.056  0.0588
# R_PGL         0.2541  0.3816  1.9920  0.3592  0.3861  0.364  0.3822
# R_GND         0.2541  0.3816  1.9920  0.3592  0.3861  0.364  0.3822
# R_AKGDH       3.1581  2.2896  3.9425  5.5227  2.4948  2.100  2.3814
# R_SUCDi       3.8115  2.9256  4.3160  5.5227  2.4948  2.156  2.4402
# R_FUM         3.8115  2.9256  4.3160  5.5227  2.4948  2.156  2.4402
# R_TPI         3.3396  2.1942  3.2785  3.5471  2.6136  2.436  2.5872
# R_FBA         3.3396  2.1942  3.2785  3.5471  2.6136  2.436  2.5872
# R_PFK         3.3396  2.1942  3.2785  3.5471  2.6136  2.436  2.5872
# R_ACONTb      4.0293  3.1482  4.5650  5.7921  2.7324  2.408  2.6754
# R_CS          4.0293  3.1482  4.5650  5.7921  2.7324  2.408  2.6754
# R_ACONTa      4.0293  3.1482  4.5650  5.7921  2.7324  2.408  2.6754
# R_GLCptspp    3.6300  3.1800  4.1500  4.4900  2.9700  2.800  2.9400
# R_ENO         6.2799  4.7064  6.7230  7.3636  4.9005  4.564  4.8510
# R_GAPD        6.5703  4.9926  7.0135  7.6779  5.1975  4.872  5.1450
#
# [28 rows x 29 columns]

# %% [markdown]
# --> In Gerosa, there are both features and reactions that are equal to one another. In Ishii, there are only reactions that are equal to one another.

# %% [markdown]
# ### Conflicts?

# %%
for gene in gexp_g.T[gexp_g.T.duplicated(keep = False)].T.columns:
    if gene in gexp_i.columns:
        print(gene)
print('completed')
# Out:
# completed

# %% [markdown]
# --> None of the duplicated genes in Gerosa are present in the ishii data. There are no conflicts there and all those extra genes can be removed.

# %%
for r in flux_g.T[flux_g.T.duplicated(keep = False)].T.columns:
    if r in flux_i.columns:
        if r not in flux_i.T[flux_i.T.duplicated(keep = False)].T.columns:
            print(r, ': duplicate only in Gerosa')

for r in flux_i.T[flux_i.T.duplicated(keep = False)].T.columns:
    if r in flux_g.columns:
        if r not in flux_g.T[flux_g.T.duplicated(keep = False)].T.columns:
            print(r, ': duplicate only in Ishii')
# Out:
# R_G6PDH2r : duplicate only in Gerosa
# R_FBA : duplicate only in Ishii
# R_TPI : duplicate only in Ishii
# R_GND : duplicate only in Ishii
# R_SUCDi : duplicate only in Ishii
# R_FUM : duplicate only in Ishii
# R_EX_lac_D_e : duplicate only in Ishii

# %% [markdown]
# --> There are some conflicts of which of the reactions in the intersection of the data that are duplicates. Keep this in mind when cleaning the data.

# %% [markdown]
# ## Zeros

# %% [markdown]
#  Even though there are no NaNs, there could still be many zeros. Check occurence of zero:

# %%
print('Gerosa')
print((gexp_g == 0).sum().sum())
print((flux_g == 0).sum().sum())
print('\nIshii')
print((gexp_i == 0).sum().sum())
print((flux_i == 0).sum().sum())
# Out:
# Gerosa
# 0
# 59
#
# Ishii
# 0
# 351

# %% [markdown]
# --> There is registered an expression level for all genes in all conditions, even knocked-out genes. There is not registered a flux for all reactions in all conditions, however. Investigate which reactions this concern and to what extent:

# %%
#Show zero count for columns with at least one zero
print('0s in Gerosa (total samples = %s)' %flux_g.shape[0])
count_g = flux_g.apply(lambda e: (e == 0).sum())
print(count_g[count_g > 0].sort_values())
print('\n0s in Ishii (total samples = %s)' %flux_i.shape[0])
count_i = flux_i.apply(lambda e: (e == 0).sum())
print(count_i[count_i > 0].sort_values())
# Out:
# 0s in Gerosa (total samples = 8)
# R_EX_fum_e      1
# R_G6PDH2r       1
# R_PGL           1
# R_EX_fru_e      7
# R_EX_gal_e      7
# R_EX_glc_e      7
# R_EX_glyc_e     7
# R_EX_glcn_e     7
# R_EX_pyr_e      7
# R_EX_succ_e     7
# R_EX_lac_D_e    7
# dtype: int64
#
# 0s in Ishii (total samples = 29)
# R_PGI            1
# R_RPE            1
# R_G6PDH2r        2
# R_PGL            2
# R_GND            2
# R_ICL            6
# R_MALS           6
# R_PPC            9
# R_TKT2          10
# R_ME2           20
# R_EX_etoh_e     24
# R_ALCD2x        25
# R_ACALD         25
# R_EX_for_e      25
# R_EX_ac_e       26
# R_PTAr          27
# R_EX_succ_e     27
# R_ACKr          27
# R_EX_pyr_e      28
# R_EX_lac_D_e    29
# R_LDH_D         29
# dtype: int64

# %% [markdown]
# --> Some reactions are mostly 0 and should be removed (R_EX_lac_D_e and R_LDH_D are always 0 in Ishii, in fact). Many of these are exchange reactions, which especially makes sense in the Gerosa data where there is only one sole carbon source for each observation.

# %% [markdown]
# ### Sole-carbon sources in Gerosa

# %%
#The carbon sources:
sorted(flux_g.index)
# Out:
# ['Acetate',
#  'Fructose',
#  'Galactose',
#  'Gluconate',
#  'Glucose',
#  'Glycerol',
#  'Pyruvate',
#  'Succinate']

# %%
#Reactions that have zero flux in all but one sample
active_once = (count_g[count_g == 7]).index.tolist()

#Find which sample the flux is non-zero in and what the value is:
for reaction in sorted(active_once):
    sample = flux_g.index[(flux_g != 0)[reaction]].tolist()
    print('%s\t%s\t%s' % (sample, 
                         reaction,
                         flux_g.loc[sample, reaction].values)
         )
# Out:
# ['Fructose']	R_EX_fru_e	[-8.328]
# ['Galactose']	R_EX_gal_e	[-1.969]
# ['Glucose']	R_EX_glc_e	[-9.654]
# ['Gluconate']	R_EX_glcn_e	[-7.28392319]
# ['Glycerol']	R_EX_glyc_e	[-10.14]
# ['Pyruvate']	R_EX_lac_D_e	[1.15701005]
# ['Pyruvate']	R_EX_pyr_e	[-26.714]
# ['Succinate']	R_EX_succ_e	[-15.902]

# %% [markdown]
# --> The carbon sources are only taken up when they are expected to. In addition, lactose is only exported when pyruvate is the source.
# However, acateate is not in the list and its exchange is thus active in more samples than when acetate is the carbon source.

# %% [markdown]
# Check where acetate is being taken up:

# %%
flux_g['R_EX_ac_e'][flux_g['R_EX_ac_e']<0]
# Out:
# Acetate     -1.358400e+01
# Galactose   -1.968940e-08
# Name: R_EX_ac_e, dtype: float64

# %% [markdown]
# The flux in the other condition is at a rate of many order of magnitude less; it is actually rounded off to zero when including up to 7 decimals.

# %%
import numpy as np
np.round(flux_g['R_EX_ac_e'], 7)
# Out:
# Acetate     -13.584000
# Fructose      3.328660
# Galactose    -0.000000
# Glucose       6.827019
# Glycerol      0.597000
# Gluconate     5.003982
# Pyruvate     11.913910
# Succinate     3.320974
# Name: R_EX_ac_e, dtype: float64

# %% [markdown]
# ### Knock-outs in ishii

# %%
[gene_name_dict, b_number_dict] = get_id_dicts(gexp_g)
# Out:
# Keep in mind that:
# * The conversion table used was for a differnt K-12 substrain: MG1655
# * only one of these duplicated b numbers were kept:
#      common_name b_number
# 915       yhiS_2    b3504
# 978         yhiS    b3504
# 2072         crl    b0240
# 3091       crl_1    b0240
# * 'Following b-numbers had no match in the conversion table and are mapped to 'unsure' names:'
# 	- b4104 -> unsure_1
# 	- b4339 -> unsure_2
# 	- b4659 -> unsure_3
# 	- b4693 -> unsure_4
# 	- b4694 -> unsure_5

# %%
#extract KO from the rows
ko_samples = gexp_i.index.drop(['WT_0.2h-1', 'WT_0.1h-1', 'WT_0.4h-1', 'WT_0.5h-1', 'WT_0.7h-1']).tolist()

#find the KO-genes in the columns
ko_genes = []
for gene in ko_samples:
    if gene in gene_name_dict.keys(): 
        if gene_name_dict[gene] in gexp_i.columns:
            ko_genes.append(gene_name_dict[gene])
ko_df = gexp_i.loc[ko_samples, ko_genes].rename(columns = b_number_dict).sort_index(axis = 0).sort_index(axis = 1)
ko_df.index.name = 'Knock-out sample'
ko_df.columns.name = 'Gene'

#color code entries
def color_low(val):
    if val < 0.0001:
        color = 'red'
    elif val < 0.001:
        color = 'orange'
    elif val < 0.01:
        color = 'black'
    else: 
        color = 'green'
    return 'color: %s' % color

print("""
Interval the expression lies within:
Green:  [0.01, ->)
Black:  [0.001, 0.01)
Orange: [0.00001, 0.001)
Red:    (<- , 0.0001)
""")

s = ko_df.style.applymap(color_low).format(precision = 4)

display(s)
# Out:
# Interval the expression lies within:
# Green:  [0.01, ->)
# Black:  [0.001, 0.01)
# Orange: [0.00001, 0.001)
# Red:    (<- , 0.0001)
# <style type="text/css">
# #T_5e6ae_row0_col0, #T_5e6ae_row1_col1, #T_5e6ae_row2_col2, #T_5e6ae_row4_col3, #T_5e6ae_row5_col4, #T_5e6ae_row6_col5, #T_5e6ae_row8_col6, #T_5e6ae_row9_col7, #T_5e6ae_row10_col8, #T_5e6ae_row11_col9, #T_5e6ae_row12_col10, #T_5e6ae_row13_col11, #T_5e6ae_row14_col12, #T_5e6ae_row15_col13, #T_5e6ae_row16_col14, #T_5e6ae_row17_col15, #T_5e6ae_row19_col17, #T_5e6ae_row20_col18, #T_5e6ae_row21_col19, #T_5e6ae_row22_col20, #T_5e6ae_row23_col21 {
6ae_row10_col7, #T_5e6ae_row10_col9, #T_5e6ae_row10_col10, #T_5e6ae_row10_col11, #T_5e6ae_row10_col12, #T_5e6ae_row10_col13, #T_5e6ae_row10_col14, #T_5e6ae_row10_col15, #T_5e6ae_row10_col17, #T_5e6ae_row10_col18, #T_5e6ae_row10_col19, #T_5e6ae_row10_col20, #T_5e6ae_row10_col21, #T_5e6ae_row11_col0, #T_5e6ae_row11_col1, #T_5e6ae_row11_col2, #T_5e6ae_row11_col4, #T_5e6ae_row11_col5, #T_5e6ae_row11_col8, #T_5e6ae_row11_col10, #T_5e6ae_row11_col11, #T_5e6ae_row11_col12, #T_5e6ae_row11_col13, #T_5e6ae_row11_col15, #T_5e6ae_row11_col17, #T_5e6ae_row11_col18, #T_5e6ae_row11_col19, #T_5e6ae_row11_col20, #T_5e6ae_row11_col21, #T_5e6ae_row12_col0, #T_5e6ae_row12_col1, #T_5e6ae_row12_col2, #T_5e6ae_row12_col3, #T_5e6ae_row12_col4, #T_5e6a ...

# %% [markdown]
# --> When knocked out, all genes are expressed below 0.001. All but one is even expressed below 0.0001, while when the given gene is not a KO, it is always expressed above 0.001, and often above 0.01. So the order of magnitude is less when knocked-out -> they are indeed inactive.

# %% [markdown]
# ## Reversible reactions

# %%
print('Reactions with only negative fluxes:')
print('Gerosa:', sorted(flux_g.columns[((flux_g.min() < 0) & (flux_g.max() <= 0))]))
print('Ishii:', sorted(flux_i.columns[((flux_i.min() < 0) & (flux_i.max() <= 0))]))

print('\nReactions spanning 0:')
print('Gerosa:', sorted(flux_g.columns[((flux_g.min() < 0) & (flux_g.max() > 0))]))
print('Ishii:', sorted(flux_i.columns[((flux_i.min() < 0) & (flux_i.max() > 0))]))
# Out:
# Reactions with only negative fluxes:
# Gerosa: ['R_EX_fru_e', 'R_EX_gal_e', 'R_EX_glc_e', 'R_EX_glcn_e', 'R_EX_glyc_e', 'R_EX_pyr_e', 'R_EX_succ_e', 'R_RPI', 'R_SUCOAS']
# Ishii: ['R_ACALD', 'R_ACKr', 'R_ALCD2x', 'R_EX_glc_e', 'R_EX_o2_e', 'R_PGK', 'R_PGM', 'R_RPI', 'R_SUCOAS']
#
# Reactions spanning 0:
# Gerosa: ['R_ENO', 'R_EX_ac_e', 'R_FBA', 'R_GAPD', 'R_PGI', 'R_PGK', 'R_PGM', 'R_PPCK', 'R_TPI']
# Ishii: ['R_RPE', 'R_TALA', 'R_TKT1', 'R_TKT2']

# %% [markdown]
# ## Ranges in data

# %% [markdown]
# Check the range of the gene expression to see whether the columns are on different scales:

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(20,15))

(gexp_g.max()-gexp_g.min()).plot(ax = ax1)
ax1.set_title('gexp g')

(flux_g.max()-flux_g.min()).plot(ax = ax2)
ax2.set_title('flux g')

(gexp_i.max()-gexp_i.min()).plot(ax = ax3)
ax3.set_title('gexp i')

(flux_i.max()-flux_i.min()).plot(ax = ax4)
ax4.set_title('flux i')

ax1.set_xticks([])
ax2.set_xticks([])
ax3.set_xticks([])
ax4.set_xticks([])

plt.suptitle('Ranges in data')
plt.show()
plt.close()
